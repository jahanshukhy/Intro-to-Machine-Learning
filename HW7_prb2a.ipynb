# %% [markdown]
# <a href="https://colab.research.google.com/github/jahanshukhy/Intro-to-Machine-Learning/blob/main/HW7_prb2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Download CIFAR-10, convert to tensor and normalize

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2470, 0.2435, 0.2616]
    ),
])

data_path = "./data-cifar10/"

trainset = datasets.CIFAR10(root=data_path, train=True, download=True, transform=transform)
valset   = datasets.CIFAR10(root=data_path, train=False, download=True, transform=transform)

trainloader = DataLoader(trainset, batch_size=128, shuffle=True)
valloader   = DataLoader(valset,   batch_size=128, shuffle=False)
# Out:
# Using device: cuda

# %%
# Build Residual block

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        # First convolution
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)

        # Second convolution
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        # shortcut path (identity or 1x1 conv with downsampling)
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1,
                          stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.shortcut = nn.Identity()

    def forward(self, x):
        identity = self.shortcut(x)

        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        out = F.relu(out + identity)
        return out

# %%
# Build ResNet-10

class ResNet10(nn.Module):
    def __init__(self):
        super().__init__()

        # Initial convolution
        self.conv_in = nn.Conv2d(3, 16, kernel_size=3, stride=1,
                                 padding=1, bias=False)
        self.bn_in = nn.BatchNorm2d(16)

        # Create layers (2 blocks per layer)
        self.layer1 = self._make_layer(16, 16, num_blocks=2, stride=1)
        self.layer2 = self._make_layer(16, 32, num_blocks=2, stride=2)
        self.layer3 = self._make_layer(32, 64, num_blocks=2, stride=2)
        self.layer4 = self._make_layer(64, 128, num_blocks=2, stride=2)

        # Global Average Pooling
        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))

        # Final fully connected layer
        self.fc = nn.Linear(128, 10)

    def _make_layer(self, in_channels, out_channels, num_blocks, stride):
        layers = []
        layers.append(ResidualBlock(in_channels, out_channels, stride))

        for _ in range(1, num_blocks):
            layers.append(ResidualBlock(out_channels, out_channels, stride=1))

        return nn.Sequential(*layers)

    def forward(self, x):

        x = F.relu(self.bn_in(self.conv_in(x)))

        x = self.layer1(x)   # 32×32
        x = self.layer2(x)   # 16×16
        x = self.layer3(x)   # 8×8
        x = self.layer4(x)   # 4×4

        x = self.avg_pool(x) # 1×1

        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

# %%
model = ResNet10().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Model size(trainable parameters):", count_params(model))
# Out:
# Model size(trainable parameters): 701466

# %%
def train_model(num_epochs=300):
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []

    start_time = time.time()

    for epoch in range(num_epochs):
        epoch_start = time.time()
        model.train()
        running_loss, correct, total = 0, 0, 0

         # Training loop
        for imgs, labels in trainloader:
            imgs, labels = imgs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(trainloader)
        train_acc  = correct / total

        # Validation loop
        model.eval()
        v_loss, v_correct, v_total = 0, 0, 0

        with torch.no_grad():
            for imgs, labels in valloader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)

                v_loss += loss.item()
                _, pred = torch.max(outputs, 1)
                v_total += labels.size(0)
                v_correct += (pred == labels).sum().item()

        val_loss = v_loss / len(valloader)
        val_acc  = v_correct / v_total

        train_losses.append(train_loss)
        train_accs.append(train_acc)
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        epoch_time = time.time() - epoch_start

        print(f"Epoch {epoch+1:3d} | Time: {epoch_time:6.2f} s | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

    total_time = (time.time() - start_time) / 60
    print(f"Training complete in {total_time:.2f} minutes")

    return train_losses, val_losses, train_accs, val_accs

# %%
# Training and plot Curves

train_losses, val_losses, train_accs, val_accs = train_model(300)

plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
plt.plot(train_losses, label="Train loss")
plt.plot(val_losses, label="Val loss")
plt.legend(), plt.title("Loss")

plt.subplot(2,1,2)
plt.plot(train_accs, label="Train acc")
plt.plot(val_accs, label="Val acc")
plt.legend(), plt.title("Accuracy")

plt.tight_layout()
plt.show()
# Out:
# Epoch   1 | Time:  22.92 s | Train Loss: 1.3216 | Val Loss: 1.1340 | Train Acc: 0.5132 | Val Acc: 0.5865
# Epoch   2 | Time:  22.30 s | Train Loss: 0.8547 | Val Loss: 0.8742 | Train Acc: 0.6952 | Val Acc: 0.6897
# Epoch   3 | Time:  21.82 s | Train Loss: 0.6611 | Val Loss: 0.7348 | Train Acc: 0.7680 | Val Acc: 0.7482
# Epoch   4 | Time:  21.91 s | Train Loss: 0.5467 | Val Loss: 0.7073 | Train Acc: 0.8090 | Val Acc: 0.7596
# Epoch   5 | Time:  21.78 s | Train Loss: 0.4551 | Val Loss: 0.6544 | Train Acc: 0.8412 | Val Acc: 0.7806
# Epoch   6 | Time:  21.88 s | Train Loss: 0.3765 | Val Loss: 0.7365 | Train Acc: 0.8678 | Val Acc: 0.7597
# Epoch   7 | Time:  21.92 s | Train Loss: 0.3060 | Val Loss: 0.7303 | Train Acc: 0.8918 | Val Acc: 0.7745
# Epoch   8 | Time:  21.96 s | Train Loss: 0.2429 | Val Loss: 0.7734 | Train Acc: 0.9151 | Val Acc: 0.7704
# Epoch   9 | Time:  22.07 s | Train Loss: 0.1990 | Val Loss: 0.9593 | Train Acc: 0.9306 | Val Acc: 0.7382
# Epoch  10 | Time:  22.12 s | Train Loss: 0.1612 | Val Loss: 0.7461 | Train Acc: 0.9431 | Val Acc: 0.7890
# Epoch  11 | Time:  22.09 s | Train Loss: 0.1326 | Val Loss: 0.8221 | Train Acc: 0.9526 | Val Acc: 0.7841
# Epoch  12 | Time:  22.13 s | Train Loss: 0.1051 | Val Loss: 0.9134 | Train Acc: 0.9634 | Val Acc: 0.7820
# Epoch  13 | Time:  22.23 s | Train Loss: 0.0916 | Val Loss: 0.8967 | Train Acc: 0.9677 | Val Acc: 0.7914
# Epoch  14 | Time:  22.15 s | Train Loss: 0.0782 | Val Loss: 1.0002 | Train Acc: 0.9722 | Val Acc: 0.7760
# Epoch  15 | Time:  22.17 s | Train Loss: 0.0782 | Val Loss: 1.0791 | Train Acc: 0.9723 | Val Acc: 0.7698
# Epoch  16 | Time:  22.17 s | Train Loss: 0.0699 | Val Loss: 1.0775 | Train Acc: 0.9750 | Val Acc: 0.7769
# Epoch  17 | Time:  22.03 s | Train Loss: 0.0618 | Val Loss: 0.9629 | Train Acc: 0.9778 | Val Acc: 0.7885
# Epoch 258 | Time:  21.66 s | Train Loss: 0.0063 | Val Loss: 1.7012 | Train Acc: 0.9980 | Val Acc: 0.8021
# Epoch 259 | Time:  21.74 s | Train Loss: 0.0068 | Val Loss: 1.6376 | Train Acc: 0.9978 | Val Acc: 0.8081
# Epoch 260 | Time:  21.71 s | Train Loss: 0.0028 | Val Loss: 1.6473 | Train Acc: 0.9991 | Val Acc: 0.8113
# Epoch 261 | Time:  21.73 s | Train Loss: 0.0020 | Val Loss: 1.6328 | Train Acc: 0.9994 | Val Acc: 0.8151
# Epoch 262 | Time:  21.66 s | Train Loss: 0.0014 | Val Loss: 1.6562 | Train Acc: 0.9995 | Val Acc: 0.8103
# Epoch 263 | Time:  21.49 s | Train Loss: 0.0026 | Val Loss: 1.7476 | Train Acc: 0.9992 | Val Acc: 0.8042
# Epoch 264 | Time:  21.63 s | Train Loss: 0.0075 | Val Loss: 1.7620 | Train Acc: 0.9977 | Val Acc: 0.8018
# Epoch 265 | Time:  21.68 s | Train Loss: 0.0069 | Val Loss: 1.6611 | Train Acc: 0.9978 | Val Acc: 0.8059
# Epoch 266 | Time:  21.75 s | Train Loss: 0.0041 | Val Loss: 1.7126 | Train Acc: 0.9983 | Val Acc: 0.8068
# Epoch 267 | Time:  21.80 s | Train Loss: 0.0026 | Val Loss: 1.6832 | Train Acc: 0.9992 | Val Acc: 0.8092
# Epoch 268 | Time:  21.68 s | Train Loss: 0.0018 | Val Loss: 1.7465 | Train Acc: 0.9993 | Val Acc: 0.8045
# Epoch 269 | Time:  21.47 s | Train Loss: 0.0074 | Val Loss: 1.7301 | Train Acc: 0.9975 | Val Acc: 0.8022
# Epoch 270 | Time:  21.57 s | Train Loss: 0.0053 | Val Loss: 1.6604 | Train Acc: 0.9981 | Val Acc: 0.8094
# Epoch 271 | Time:  21.48 s | Train Loss: 0.0027 | Val Loss: 1.6729 | Train Acc: 0.9992 | Val Acc: 0.8084
# Epoch 272 | Time:  21.53 s | Train Loss: 0.0026 | Val Loss: 1.6566 | Train Acc: 0.9992 | Val Acc: 0.8077
# Epoch 273 | Time:  21.51 s | Train Loss: 0.0019 | Val Loss: 1.6610 | Train Acc: 0.9994 | Val Acc: 0.8105
# Epoch 274 | Time:  21.42 s | Train Loss: 0.0043 | Val Loss: 1.7270 | Train Acc: 0.9985 | Val Acc: 0.8025
# Epoch 275 | Time:  21.33 s | Train Loss: 0.0080 | Val Loss: 1.6546 | Train Acc: 0.9971 | Val Acc: 0.8068
# Epoch 276 | Time:  21.50 s | Train Loss: 0.0039 | Val Loss: 1.5970 | Train Acc: 0.9986 | Val Acc: 0.8125
# Epoch 277 | Time:  21.36 s | Train Loss: 0.0027 | Val Loss: 1.6710 | Train Acc: 0.9990 | Val Acc: 0.8099
# Epoch 278 | Time:  21.41 s | Train Loss: 0.0018 | Val Loss: 1.6490 | Train Acc: 0.9995 | Val Acc: 0.8124
# Epoch 279 | Time:  21.53 s | Train Loss: 0.0020 | Val Loss: 1.7062 | Train Acc: 0.9993 | Val Acc: 0.8060
# Epoch 280 | Time:  21.44 s | Train Loss: 0.0026 | Val Loss: 1.6422 | Train Acc: 0.9991 | Val Acc: 0.8111
# Epoch 281 | Time:  21.48 s | Train Loss: 0.0048 | Val Loss: 1.7053 | Train Acc: 0.9985 | Val Acc: 0.8069
# Epoch 282 | Time:  21.51 s | Train Loss: 0.0051 | Val Loss: 1.7091 | Train Acc: 0.9983 | Val Acc: 0.8068
# Epoch 283 | Time:  21.51 s | Train Loss: 0.0041 | Val Loss: 1.7087 | Train Acc: 0.9986 | Val Acc: 0.8042
# Epoch 284 | Time:  21.27 s | Train Loss: 0.0036 | Val Loss: 1.6908 | Train Acc: 0.9988 | Val Acc: 0.8066
# Epoch 285 | Time:  21.29 s | Train Loss: 0.0015 | Val Loss: 1.6494 | Train Acc: 0.9996 | Val Acc: 0.8145
# Epoch 286 | Time:  21.17 s | Train Loss: 0.0010 | Val Loss: 1.6442 | Train Acc: 0.9997 | Val Acc: 0.8150
# Epoch 287 | Time:  21.23 s | Train Loss: 0.0005 | Val Loss: 1.6291 | Train Acc: 0.9999 | Val Acc: 0.8122
# Epoch 288 | Time:  21.22 s | Train Loss: 0.0020 | Val Loss: 1.8477 | Train Acc: 0.9993 | Val Acc: 0.8002
# Epoch 289 | Time:  21.44 s | Train Loss: 0.0131 | Val Loss: 1.7339 | Train Acc: 0.9959 | Val Acc: 0.8034
# Epoch 290 | Time:  21.56 s | Train Loss: 0.0074 | Val Loss: 1.6176 | Train Acc: 0.9976 | Val Acc: 0.8115
# Epoch 291 | Time:  21.35 s | Train Loss: 0.0022 | Val Loss: 1.6551 | Train Acc: 0.9992 | Val Acc: 0.8124
# Epoch 292 | Time:  21.32 s | Train Loss: 0.0019 | Val Loss: 1.6811 | Train Acc: 0.9993 | Val Acc: 0.8127
# Epoch 293 | Time:  21.48 s | Train Loss: 0.0018 | Val Loss: 1.6600 | Train Acc: 0.9995 | Val Acc: 0.8138
# Epoch 294 | Time:  21.42 s | Train Loss: 0.0023 | Val Loss: 1.7258 | Train Acc: 0.9993 | Val Acc: 0.8057
# Epoch 295 | Time:  21.35 s | Train Loss: 0.0051 | Val Loss: 1.6760 | Train Acc: 0.9985 | Val Acc: 0.8136
# Epoch 296 | Time:  21.37 s | Train Loss: 0.0065 | Val Loss: 1.7232 | Train Acc: 0.9977 | Val Acc: 0.8099
# Epoch 297 | Time:  21.36 s | Train Loss: 0.0055 | Val Loss: 1.6516 | Train Acc: 0.9982 | Val Acc: 0.8151
# Epoch 298 | Time:  21.19 s | Train Loss: 0.0024 | Val Loss: 1.6630 | Train Acc: 0.9991 | Val Acc: 0.8134
# Epoch 299 | Time:  21.45 s | Train Loss: 0.0013 | Val Loss: 1.6729 | Train Acc: 0.9996 | Val Acc: 0.8138
# Epoch 300 | Time:  21.22 s | Train Loss: 0.0016 | Val Loss: 1.7132 | Train Acc: 0.9996 | Val Acc: 0.8169
# Training complete in 108.97 minutes
