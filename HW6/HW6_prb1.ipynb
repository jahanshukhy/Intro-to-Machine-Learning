# %% [markdown]
# <a href="https://colab.research.google.com/github/jahanshukhy/Intro-to-Machine-Learning/blob/main/HW6_prb1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from google.colab import drive

drive.mount('/content/drive')
def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(0)


plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["font.size"] = 12

# Load diabetes dataset

file_path = '/content/drive/My Drive/ML/HW3/diabetes.csv'
df = pd.DataFrame(pd.read_csv(file_path))
df.head()
print(df.head())
print(df.shape)

# Features (X) and label (y)
X = df.drop('Outcome', axis=1).values.astype(np.float32)
y = df['Outcome'].values.astype(np.float32)

# Train / validation split (80/20)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.20, random_state=0, stratify=y
)

print("Train shape:", X_train.shape, "Val shape:", X_val.shape)
# Out:
# Mounted at /content/drive
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# (768, 9)
# Train shape: (614, 8) Val shape: (154, 8)

# %%
# Feature scaling (Standardization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train).astype(np.float32)
X_val_scaled   = scaler.transform(X_val).astype(np.float32)

# Convert to PyTorch tensors & move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

X_train_tensor = torch.tensor(X_train_scaled, device=device)
y_train_tensor = torch.tensor(y_train.reshape(-1, 1), device=device)

X_val_tensor   = torch.tensor(X_val_scaled, device=device)
y_val_tensor   = torch.tensor(y_val.reshape(-1, 1), device=device)
# Out:
# Using device: cpu

# %%
# Define fully connected neural network

class DiabetesNet(nn.Module):
    def __init__(self, input_dim=8):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Dropout(p=0.3),
            nn.Linear(8, 1)
        )

    def forward(self, x):
        return self.net(x)

model = DiabetesNet(input_dim=X_train.shape[1]).to(device)
print(model)

# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-3)
# Out:
# DiabetesNet(
#   (net): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=16, out_features=8, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=8, out_features=1, bias=True)
#   )
# )

# %%
# Training loop

n_epochs   = 100
batch_size = 64
patience   = 10

train_losses = []
val_losses   = []

best_val_loss   = float('inf')
best_state_dict = None
epochs_no_improve = 0

def iterate_minibatches(X_tensor, y_tensor, batch_size):
    N = X_tensor.shape[0]
    indices = torch.randperm(N, device=device)
    for i in range(0, N, batch_size):
        idx = indices[i:i+batch_size]
        yield X_tensor[idx], y_tensor[idx]

for epoch in range(1, n_epochs + 1):
    model.train()

    for xb, yb in iterate_minibatches(X_train_tensor, y_train_tensor, batch_size):
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

    # Validation
    model.eval()
    with torch.no_grad():
        train_logits = model(X_train_tensor)
        epoch_train_loss = criterion(train_logits, y_train_tensor).item()
        val_logits = model(X_val_tensor)
        val_loss = criterion(val_logits, y_val_tensor).item()

    train_losses.append(epoch_train_loss)
    val_losses.append(val_loss)
    if val_loss < best_val_loss - 1e-4:
        best_val_loss   = val_loss
        best_state_dict = model.state_dict()
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1

    print(f"Epoch {epoch:3d} | Train loss: {epoch_train_loss:.4f} | Val loss: {val_loss:.4f} | "
          f"No improve: {epochs_no_improve}")

    if epochs_no_improve >= patience:
        print(f"\nEarly stopping at epoch {epoch} (best val loss = {best_val_loss:.4f})")
        break

# Load best model weights (at lowest validation loss)
if best_state_dict is not None:
    model.load_state_dict(best_state_dict)



# Plot train vs validation loss
plt.plot(train_losses, label='Train loss')
plt.plot(val_losses,   label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Neural Network: Train vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch   1 | Train loss: 0.6797 | Val loss: 0.6805 | No improve: 0
# Epoch   2 | Train loss: 0.6755 | Val loss: 0.6756 | No improve: 0
# Epoch   3 | Train loss: 0.6710 | Val loss: 0.6706 | No improve: 0
# Epoch   4 | Train loss: 0.6660 | Val loss: 0.6652 | No improve: 0
# Epoch   5 | Train loss: 0.6603 | Val loss: 0.6592 | No improve: 0
# Epoch   6 | Train loss: 0.6541 | Val loss: 0.6528 | No improve: 0
# Epoch   7 | Train loss: 0.6477 | Val loss: 0.6460 | No improve: 0
# Epoch   8 | Train loss: 0.6405 | Val loss: 0.6384 | No improve: 0
# Epoch   9 | Train loss: 0.6326 | Val loss: 0.6301 | No improve: 0
# Epoch  10 | Train loss: 0.6241 | Val loss: 0.6208 | No improve: 0
# Epoch  11 | Train loss: 0.6156 | Val loss: 0.6115 | No improve: 0
# Epoch  12 | Train loss: 0.6071 | Val loss: 0.6021 | No improve: 0
# Epoch  13 | Train loss: 0.5973 | Val loss: 0.5916 | No improve: 0
# Epoch  14 | Train loss: 0.5875 | Val loss: 0.5807 | No improve: 0
# Epoch  15 | Train loss: 0.5774 | Val loss: 0.5696 | No improve: 0
# Epoch  16 | Train loss: 0.5677 | Val loss: 0.5587 | No improve: 0
# Epoch  17 | Train loss: 0.5590 | Val loss: 0.5488 | No improve: 0
# Epoch  18 | Train loss: 0.5492 | Val loss: 0.5377 | No improve: 0
# Epoch  19 | Train loss: 0.5404 | Val loss: 0.5275 | No improve: 0
# Epoch  20 | Train loss: 0.5337 | Val loss: 0.5197 | No improve: 0
# Epoch  21 | Train loss: 0.5275 | Val loss: 0.5123 | No improve: 0
# Epoch  22 | Train loss: 0.5211 | Val loss: 0.5041 | No improve: 0
# Epoch  23 | Train loss: 0.5150 | Val loss: 0.4962 | No improve: 0
# Epoch  24 | Train loss: 0.5107 | Val loss: 0.4905 | No improve: 0
# Epoch  25 | Train loss: 0.5063 | Val loss: 0.4845 | No improve: 0
# Epoch  26 | Train loss: 0.5026 | Val loss: 0.4793 | No improve: 0
# Epoch  27 | Train loss: 0.4997 | Val loss: 0.4745 | No improve: 0
# Epoch  28 | Train loss: 0.4970 | Val loss: 0.4697 | No improve: 0
# Epoch  29 | Train loss: 0.4947 | Val loss: 0.4659 | No improve: 0
# Epoch  30 | Train loss: 0.4918 | Val loss: 0.4621 | No improve: 0
# Epoch  31 | Train loss: 0.4896 | Val loss: 0.4586 | No improve: 0
# Epoch  32 | Train loss: 0.4875 | Val loss: 0.4547 | No improve: 0
# Epoch  33 | Train loss: 0.4864 | Val loss: 0.4524 | No improve: 0
# Epoch  34 | Train loss: 0.4850 | Val loss: 0.4494 | No improve: 0
# Epoch  35 | Train loss: 0.4840 | Val loss: 0.4485 | No improve: 0
# Epoch  36 | Train loss: 0.4833 | Val loss: 0.4473 | No improve: 0
# Epoch  37 | Train loss: 0.4824 | Val loss: 0.4459 | No improve: 0
# Epoch  38 | Train loss: 0.4814 | Val loss: 0.4447 | No improve: 0
# Epoch  39 | Train loss: 0.4810 | Val loss: 0.4440 | No improve: 0
# Epoch  40 | Train loss: 0.4803 | Val loss: 0.4425 | No improve: 0
# Epoch  41 | Train loss: 0.4794 | Val loss: 0.4411 | No improve: 0
# Epoch  42 | Train loss: 0.4787 | Val loss: 0.4400 | No improve: 0
# Epoch  43 | Train loss: 0.4779 | Val loss: 0.4391 | No improve: 0
# Epoch  44 | Train loss: 0.4772 | Val loss: 0.4384 | No improve: 0
# Epoch  45 | Train loss: 0.4765 | Val loss: 0.4365 | No improve: 0
# Epoch  46 | Train loss: 0.4759 | Val loss: 0.4360 | No improve: 0
# Epoch  47 | Train loss: 0.4751 | Val loss: 0.4347 | No improve: 0
# Epoch  48 | Train loss: 0.4747 | Val loss: 0.4341 | No improve: 0
# Epoch  49 | Train loss: 0.4742 | Val loss: 0.4339 | No improve: 0
# Epoch  50 | Train loss: 0.4737 | Val loss: 0.4327 | No improve: 0
# Epoch  51 | Train loss: 0.4732 | Val loss: 0.4319 | No improve: 0
# Epoch  52 | Train loss: 0.4728 | Val loss: 0.4317 | No improve: 0
# Epoch  53 | Train loss: 0.4723 | Val loss: 0.4309 | No improve: 0
# Epoch  54 | Train loss: 0.4723 | Val loss: 0.4311 | No improve: 1
# Epoch  55 | Train loss: 0.4718 | Val loss: 0.4303 | No improve: 0
# Epoch  56 | Train loss: 0.4719 | Val loss: 0.4304 | No improve: 1
# Epoch  57 | Train loss: 0.4718 | Val loss: 0.4299 | No improve: 0
# Epoch  58 | Train loss: 0.4709 | Val loss: 0.4290 | No improve: 0
# Epoch  59 | Train loss: 0.4704 | Val loss: 0.4283 | No improve: 0
# Epoch  60 | Train loss: 0.4701 | Val loss: 0.4289 | No improve: 1
# Epoch  61 | Train loss: 0.4697 | Val loss: 0.4284 | No improve: 2
# Epoch  62 | Train loss: 0.4691 | Val loss: 0.4274 | No improve: 0
# Epoch  63 | Train loss: 0.4690 | Val loss: 0.4274 | No improve: 1
# Epoch  64 | Train loss: 0.4688 | Val loss: 0.4268 | No improve: 0
# Epoch  65 | Train loss: 0.4688 | Val loss: 0.4267 | No improve: 0
# Epoch  66 | Train loss: 0.4686 | Val loss: 0.4265 | No improve: 0
# Epoch  67 | Train loss: 0.4681 | Val loss: 0.4261 | No improve: 0
# Epoch  68 | Train loss: 0.4677 | Val loss: 0.4258 | No improve: 0
# Epoch  69 | Train loss: 0.4675 | Val loss: 0.4252 | No improve: 0
# Epoch  70 | Train loss: 0.4674 | Val loss: 0.4250 | No improve: 0
# Epoch  71 | Train loss: 0.4671 | Val loss: 0.4247 | No improve: 0
# Epoch  72 | Train loss: 0.4670 | Val loss: 0.4249 | No improve: 1
# Epoch  73 | Train loss: 0.4668 | Val loss: 0.4245 | No improve: 0
# Epoch  74 | Train loss: 0.4667 | Val loss: 0.4242 | No improve: 0
# Epoch  75 | Train loss: 0.4664 | Val loss: 0.4229 | No improve: 0
# Epoch  76 | Train loss: 0.4661 | Val loss: 0.4219 | No improve: 0
# Epoch  77 | Train loss: 0.4660 | Val loss: 0.4225 | No improve: 1
# Epoch  78 | Train loss: 0.4660 | Val loss: 0.4226 | No improve: 2
# Epoch  79 | Train loss: 0.4660 | Val loss: 0.4228 | No improve: 3
# Epoch  80 | Train loss: 0.4658 | Val loss: 0.4225 | No improve: 4
# Epoch  81 | Train loss: 0.4656 | Val loss: 0.4225 | No improve: 5
# Epoch  82 | Train loss: 0.4653 | Val loss: 0.4222 | No improve: 6
# Epoch  83 | Train loss: 0.4649 | Val loss: 0.4210 | No improve: 0
# Epoch  84 | Train loss: 0.4648 | Val loss: 0.4204 | No improve: 0
# Epoch  85 | Train loss: 0.4644 | Val loss: 0.4198 | No improve: 0
# Epoch  86 | Train loss: 0.4643 | Val loss: 0.4208 | No improve: 1
# Epoch  87 | Train loss: 0.4641 | Val loss: 0.4203 | No improve: 2
# Epoch  88 | Train loss: 0.4639 | Val loss: 0.4201 | No improve: 3
# Epoch  89 | Train loss: 0.4637 | Val loss: 0.4195 | No improve: 0
# Epoch  90 | Train loss: 0.4637 | Val loss: 0.4194 | No improve: 0
# Epoch  91 | Train loss: 0.4636 | Val loss: 0.4189 | No improve: 0
# Epoch  92 | Train loss: 0.4637 | Val loss: 0.4194 | No improve: 1
# Epoch  93 | Train loss: 0.4635 | Val loss: 0.4197 | No improve: 2
# Epoch  94 | Train loss: 0.4636 | Val loss: 0.4206 | No improve: 3
# Epoch  95 | Train loss: 0.4633 | Val loss: 0.4212 | No improve: 4
# Epoch  96 | Train loss: 0.4629 | Val loss: 0.4204 | No improve: 5
# Epoch  97 | Train loss: 0.4627 | Val loss: 0.4202 | No improve: 6
# Epoch  98 | Train loss: 0.4625 | Val loss: 0.4196 | No improve: 7
# Epoch  99 | Train loss: 0.4622 | Val loss: 0.4196 | No improve: 8
# Epoch 100 | Train loss: 0.4625 | Val loss: 0.4197 | No improve: 9

# %%
# Metrics for Neural Network

model.eval()
with torch.no_grad():
    val_logits = model(X_val_tensor)
    val_probs  = torch.sigmoid(val_logits).cpu().numpy().ravel()
    val_pred   = (val_probs >= 0.5).astype(int)

y_val_np = y_val.astype(int)

nn_acc  = accuracy_score(y_val_np, val_pred)
nn_prec = precision_score(y_val_np, val_pred, zero_division=0)
nn_rec  = recall_score(y_val_np, val_pred, zero_division=0)
nn_f1   = f1_score(y_val_np, val_pred, zero_division=0)

print("Neural Network Results")
print(f"Accuracy : {nn_acc:.4f}")
print(f"Precision: {nn_prec:.4f}")
print(f"Recall   : {nn_rec:.4f}")
print(f"F1 Score : {nn_f1:.4f}")
# Out:
# Neural Network Results
# Accuracy : 0.7987
# Precision: 0.7556
# Recall   : 0.6296
# F1 Score : 0.6869

# %%
# Logistic Regression (sklearn)

log_reg = LogisticRegression(
    max_iter=1000,
    solver='lbfgs'
)

log_reg.fit(X_train_scaled, y_train)
log_pred = log_reg.predict(X_val_scaled)

log_acc  = accuracy_score(y_val_np, log_pred)
log_prec = precision_score(y_val_np, log_pred, zero_division=0)
log_rec  = recall_score(y_val_np, log_pred, zero_division=0)
log_f1   = f1_score(y_val_np, log_pred, zero_division=0)

print("\nLogistic Regression Results")
print(f"Accuracy : {log_acc:.4f}")
print(f"Precision: {log_prec:.4f}")
print(f"Recall   : {log_rec:.4f}")
print(f"F1 Score : {log_f1:.4f}")
# Out:
# Logistic Regression Results
# Accuracy : 0.7792
# Precision: 0.7381
# Recall   : 0.5741
# F1 Score : 0.6458

# %%
# Support Vector Machine (SVM)

svm_clf = SVC(
    kernel='rbf',
    C=10,
    gamma=0.01,
    random_state=42
)

svm_clf.fit(X_train_scaled, y_train)
svm_pred = svm_clf.predict(X_val_scaled)

svm_acc  = accuracy_score(y_val_np, svm_pred)
svm_prec = precision_score(y_val_np, svm_pred, zero_division=0)
svm_rec  = recall_score(y_val_np, svm_pred, zero_division=0)
svm_f1   = f1_score(y_val_np, svm_pred, zero_division=0)

print("\nSVM Results (RBF kernel)")
print(f"Accuracy : {svm_acc:.4f}")
print(f"Precision: {svm_prec:.4f}")
print(f"Recall   : {svm_rec:.4f}")
print(f"F1 Score : {svm_f1:.4f}")
# Out:
# SVM Results (RBF kernel)
# Accuracy : 0.7922
# Precision: 0.7619
# Recall   : 0.5926
# F1 Score : 0.6667

# %%
# Comparison all three models
results = pd.DataFrame({
    "Model": ["Neural Network", "Logistic Regression", "SVM (RBF)"],
    "Accuracy":  [nn_acc,  log_acc,  svm_acc],
    "Precision": [nn_prec, log_prec, svm_prec],
    "Recall":    [nn_rec,  log_rec,  svm_rec],
    "F1 Score":  [nn_f1,   log_f1,   svm_f1]
})

print("\nModel Comparison")
print(results.to_string(index=False))
# Out:
# Model Comparison
#               Model  Accuracy  Precision   Recall  F1 Score
#      Neural Network  0.798701   0.755556 0.629630  0.686869
# Logistic Regression  0.779221   0.738095 0.574074  0.645833
#           SVM (RBF)  0.792208   0.761905 0.592593  0.666667

# %%
#Confusion matrices plot
def plot_confusion(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap="Blues", values_format="d")
    plt.title(title)
    plt.show()

plot_confusion(y_val_np, val_pred,
               "NN Confusion Matrix")

plot_confusion(y_val_np, log_pred,
               "Logistic Regression Confusion Matrix")

plot_confusion(y_val_np, svm_pred,
               "SVM (RBF) Confusion Matrix")
